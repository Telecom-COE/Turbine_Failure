# %%
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:/Users/ravindher.madishetty/Desktop/Logistic_Regression/Turbine_Failure/data/turbine_data.csv')

# Show the first few rows of the dataset
df.head()

# Overview of the dataset
df.info()

# Check for missing values
df.isnull().sum()

# Visualize distribution of 'temperature', 'pressure', 'vibration'
df[['temperature', 'pressure', 'vibration','humidity','wind_speed']].hist(bins=20, figsize=(12, 8))
plt.suptitle('Feature Distributions')
plt.show()

# Visualize the target variable 'failure' distribution
sns.countplot(x='failure', data=df)
plt.title('Failure Distribution')
plt.show()

# Correlation Matrix
# Select only numeric columns before calculating correlation
numeric_df = df.select_dtypes(include=[np.number])

# Plot the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35425 entries, 0 to 35424
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    35425 non-null  object
#  1   temperature  35425 non-null  float64
#  2   pressure     35425 non-null  float64
#  3   vibration    35425 non-null  float64
#  4   humidity     35425 non-null  float64
#  5   wind_speed   35425 non-null  float64
#  6   failure      35425 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.9+ MB
